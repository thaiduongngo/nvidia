# %%
from openai import OpenAI
from dotenv import load_dotenv
from typing import List

import os

# %%
load_dotenv()
# Out:
# True

# %%
client = OpenAI(
    base_url = "https://integrate.api.nvidia.com/v1",
    api_key = os.environ.get("NVIDIA_API_KEY")
)


def _build_message(message: str, role: str):
    return {
        "role": role,
        "content": message
    }


def generate_content(prompts: List, system_prompt: str=None):
    messages = []
    if system_prompt is not None:
        messages.append(_build_message(message=system_prompt, role="system"))

    for p in prompts:
        messages.append(_build_message(message=p, role="user"))
   
    return client.chat.completions.create(
        model="nvidia/llama-3.1-nemotron-70b-instruct",
        messages=messages,
        temperature=0,
        top_p=1,
        max_tokens=4096,
        stream=True
    )


def display_content(completion):
    for chunk in completion:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")

# %%
completion = generate_content(["Solve this equation:", "2x^2 - 3x + 7 = 0"])

display_content(completion)
# Out:
# A quadratic equation!
#
# To solve the equation **2x^2 - 3x + 7 = 0**, we can try various methods. Since this equation doesn't factor easily, we'll use the **Quadratic Formula**. The Quadratic Formula is:
#
# **x = (-b ± √(b^2 - 4ac)) / 2a**
#
# where **a**, **b**, and **c** are the coefficients from the equation **ax^2 + bx + c = 0**.
#
# Let's identify the coefficients in our equation:
#
# * **a = 2** (coefficient of x^2)
# * **b = -3** (coefficient of x)
# * **c = 7** (constant term)
#
# Now, plug these values into the Quadratic Formula:
#
# **x = (-(−3) ± √((−3)^2 - 4(2)(7))) / 2(2)**
# **x = (3 ± √(9 - 56)) / 4**
# **x = (3 ± √(-47)) / 4**
#
# Here's where things get interesting:
#
# * **√(-47)** is an imaginary number, since you can't find the square root of a negative number in the real number system.
# * In mathematics, we denote the square root of -1 as **i** (the imaginary unit). So, **√(-47) = √(-1) * √47 = i√47**
#
# So, the solutions to the equation are:
#
# **x = (3 ± i√47) / 4**
#
# * **x = (3 + i√47) / 4** (one complex solution)
# * **x = (3 - i√47) / 4** (the other complex solution)
#
# **No Real Solutions**: Unfortunately, this equation has no real solutions, only complex ones. This means that if you're dealing with a physical or practical problem that requires real solutions, this equation might not provide a meaningful answer in the context of that problem. However, in algebra, complex solutions are perfectly valid and can be useful in various mathematical contexts.

# %%
prompts1 = [
    """
    Write a simple C++ code in standard C++23 to construct a linked list with a few testcases and display on console.
    """
] 

completion = generate_content(prompts=prompts1, system_prompt="You are a reliable C++ developer.")

display_content(completion)
# Out:
# Below is a simple implementation of a singly linked list in C++23. This example includes basic operations: `insertNode` at the end of the list, `deleteNode` by value, and `displayList` to print the list's elements to the console. The test cases demonstrate how to use these operations.
#
# ```cpp
# #include <iostream>
#
# // Node structure for the linked list
# struct Node {
#     int data;
#     Node* next;
# };
#
# // Linked list class with basic operations
# class LinkedList {
# private:
#     Node* head; // Head of the list
#     Node* tail; // Tail of the list (for efficient append)
#
# public:
#     // Constructor
#     LinkedList() : head(nullptr), tail(nullptr) {}
#
#     // Destructor to free allocated memory
#     ~LinkedList() {
#         while (head) {
#             Node* temp = head;
#             head = head->next;
#             delete temp;
#         }
#     }
#
#     // Insert a new node at the end of the list
#     void insertNode(int value) {
#         Node* newNode = new Node{value, nullptr};
#         if (!head) {
#             head = tail = newNode;
#         } else {
#             tail->next = newNode;
#             tail = newNode;
#         }
#     }
#
#     // Delete the first occurrence of a node with the given value
#     void deleteNode(int value) {
#         if (!head) return; // List is empty
#
#         // Check if the node to be deleted is the head
#         if (head->data == value) {
#             Node* temp = head;
#             head = head->next;
#             delete temp;
#             if (!head) tail = nullptr; // List becomes empty
#             return;
#         }
#
#         // Traverse the list to find the node to delete
#         Node* prev = head;
#         Node* current = head->next;
#         while (current) {
#             if (current->data == value) {
#                 prev->next = current->next;
#                 if (current == tail) tail = prev; // Update tail if last node is deleted
#                 delete current;
#                 return;
#             }
#             prev = current;
#             current = current->next;
#         }
#     }
#
#     // Display the linked list
#     void displayList() const {
#         Node* temp = head;
#         while (temp) {
#             std::cout << temp->data << " ";
#             temp = temp->next;
#         }
#         std::cout << std::endl;
#     }
# };
#
# int main() {
#     LinkedList list;
#
#     // Test case 1: Insert nodes
#     std::cout << "Linked List after inserting nodes:" << std::endl;
#     list.insertNode(10);
#     list.insertNode(20);
#     list.insertNode(30);
#     list.insertNode(40);
#     list.displayList(); // Expected output: 10 20 30 40
#
#     // Test case 2: Delete a node
#     std::cout << "\nLinked List after deleting node 20:" << std::endl;
#     list.deleteNode(20);
#     list.displayList(); // Expected output: 10 30 40
#
#     // Test case 3: Delete head node
#     std::cout << "\nLinked List after deleting head node 10:" << std::endl;
#     list.deleteNode(10);
#     list.displayList(); // Expected output: 30 40
#
#     // Test case 4: Delete last node
#     std::cout << "\nLinked List after deleting last node 40:" << std::endl;
#     list.deleteNode(40);
#     list.displayList(); // Expected output: 30
#
#     // Test case 5: Attempt to delete a non-existent node
#     std::cout << "\nAttempting to delete non-existent node 50..." << std::endl;
#     list.deleteNode(50);
#     std::cout << "Linked List remains:" << std::endl;
#     list.displayList(); // Expected output: 30
#
#     return 0;
# }
# ```
#
# ### Key Points:
# - **Memory Management**: The `LinkedList` class properly manages memory through its constructor, destructor, and member functions to prevent leaks.
# - **Efficient Insertion**: Insertion at the end is O(1) because we maintain a `tail` pointer.
# - **Deletion**: Handles deletion of the head, tail, and any node in between. If the node to be deleted is not found, the list remains unchanged.
# - **Display**: Prints the current state of the linked list to the console.
# - **Test Cases**: Demonstrates various scenarios, including inserting nodes, deleting nodes from different positions, and attempting to delete a non-existent node.
